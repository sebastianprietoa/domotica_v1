# %% [markdown]
# # Legacy notebook
#
# Este notebook fue saneado y movido a `legacy/` porque antes contenia secretos hardcodeados.
#
# No debe usarse en produccion. Usa `.env`, `config/config.yaml` y los scripts de `scripts/`.
